# %% [markdown]
# <a href="https://colab.research.google.com/github/priyankalashkari/ml-programs/blob/main/ML_Programs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.	WAP in Python to make a list of name , Marks & plot in Bar, scatterplot & plot

# %%
import matplotlib.pyplot as plt

# Sample data
names = ['Alice', 'Bob', 'Charlie', 'David']
marks = [85, 72, 90, 78]

# Bar plot
plt.bar(names, marks)
plt.xlabel('Names')
plt.ylabel('Marks')
plt.title('Bar Plot of Marks')
plt.show()

# Scatter plot
plt.scatter(names, marks)
plt.xlabel('Names')
plt.ylabel('Marks')
plt.title('Scatter Plot of Marks')
plt.show()

# Plot
plt.plot(names, marks)
plt.xlabel('Names')
plt.ylabel('Marks')
plt.title('Plot of Marks')
plt.show()

# %% [markdown]
# 2.	Take a csv file( Iris Data, Titanic Data, Cancer data and do the basic EDA Operation

# %%
import pandas as pd

# Load the dataset (replace 'iris.csv' with your file)
data = pd.read_csv('iris.csv')

# Basic EDA operations
print("Shape:", data.shape)
print("Columns:", data.columns)
print("Head:\n", data.head())
print("Null values:\n", data.isnull().sum())
print("Unique values:\n", data.nunique())
print("Describe:\n", data.describe())

# %% [markdown]
# 3.	Take a set of Data in List & perform Normalization using Standard Scaler

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

# Sample data
data = [1, 2, 3, 4, 5]

# Create a StandardScaler object
scaler = StandardScaler()

# Reshape the data to a 2D array
data_reshaped = np.array(data).reshape(-1, 1)

# Fit the scaler to the data and transform it
normalized_data = scaler.fit_transform(data_reshaped)

# Print the normalized data
print(normalized_data)
# Out:
# [[-1.41421356]
#  [-0.70710678]
#  [ 0.        ]
#  [ 0.70710678]
#  [ 1.41421356]]

# %% [markdown]
# 4.
# Wap in Python to demonstrate a comparative study of various ML Models such as SVM, KNN,

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Load the iris dataset
from sklearn.datasets import load_iris
iris = load_iris()

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.3)

# SVM model
svm_model = SVC()
svm_model.fit(X_train, y_train)
svm_predictions = svm_model.predict(X_test)
svm_accuracy = accuracy_score(y_test, svm_predictions)

# KNN model
knn_model = KNeighborsClassifier()
knn_model.fit(X_train, y_train)
knn_predictions = knn_model.predict(X_test)
knn_accuracy = accuracy_score(y_test, knn_predictions)

# Print the accuracies
print("SVM Accuracy:", svm_accuracy)
print("KNN Accuracy:", knn_accuracy)
# Out:
# SVM Accuracy: 1.0
# KNN Accuracy: 0.9555555555555556

# %% [markdown]
# 5. WAP to demonstrate the creation of Confusion Matrix.

# %%
from sklearn.metrics import confusion_matrix

# Assuming you have y_true (true labels) and y_pred (predicted labels)
# from a previous model (e.g., SVM or KNN)
# Replace 'svm_predictions' with 'knn_predictions' if you want to evaluate the KNN model
y_true = y_test  # True labels from your test set
y_pred = svm_predictions # Predicted labels from your SVM model


# Create the confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Print the confusion matrix
print(cm)
# Out:
# [[12  0  0]
#  [ 0 18  0]
#  [ 0  0 15]]

# %% [markdown]
# 6. Wap in Python to demonstarte the usage of co-relation Matrix.

# %%
import pandas as pd

# Assuming you have data as a list:
data_list = [1, 2, 3, 4, 5]

# Convert the list to a Pandas Series or DataFrame
# A Series is sufficient for a single variable correlation, but a DataFrame is needed for multiple variables
data = pd.DataFrame({'values': data_list}) # Creating a DataFrame with one column named 'values'

# Now you can calculate the correlation (although it doesn't make much sense for a single variable)
correlation_matrix = data.corr()

# Print the correlation matrix
print(correlation_matrix)
# Out:
#         values
# values     1.0

# %% [markdown]
# 7. Wap in Python to demonstarte the usage of MacCulloch-Pitts Neuron model.

# %%
import numpy as np

def mcculloch_pitts(inputs, weights, threshold):
  """
  Implements the McCulloch-Pitts neuron model.

  Args:
    inputs: A list of input values (0 or 1).
    weights: A list of weights

# %% [markdown]
# 8. Write a Program to demonstrate the usage of perceptron network.

# %%
import numpy as np

class Perceptron:
    def __init__(self, learning_rate=0.1, epochs=100):
        self.learning_rate = learning_rate
        self.epochs = epochs
        self.weights = None
        self.bias = None

    def fit(self, X, y):
        n_samples, n_features = X.shape
        self.weights = np.zeros(n_features)
        self.bias = 0

        for _ in range(self.epochs):
            for i in range(n_samples):
                linear_output = np.dot(X[i], self.weights) + self.bias
                y_predicted = self.activation_function(linear_output)

                update = self.learning_rate * (y[i] - y_predicted)
                self.weights += update * X[i]
                self.bias += update

    def predict(self, X):
        linear_output = np.dot(X, self.weights) + self.bias
        y_predicted = self.activation_function(linear_output)
        return y_predicted

    def activation_function(self, x):
        return np.where(x >= 0, 1, 0)

# Sample data
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([0, 0, 0, 1])  # AND gate logic

# Create and train the perceptron
perceptron = Perceptron()
perceptron.fit(X, y)

# Make predictions
predictions = perceptron.predict(X)
print("Predictions:", predictions)
# Out:
# Predictions: [0 0 0 1]

# %% [markdown]
# 9. Write a Program to demonstrate the usage of a Hebbian Network.

# %%
import numpy as np

class HebbianNetwork:
    def __init__(self, learning_rate=0.1):
        self.learning_rate = learning_rate
        self.weights = None

    def fit(self, X):
        n_samples, n_features = X.shape
        self.weights = np.zeros((n_features, n_features))

        for i in range(n_samples):
            self.weights += self.learning_rate * np.outer(X[i], X[i])

    def predict(self, x):
        return np.dot(x, self.weights)

# Sample data (patterns)
X = np.array([[1, 1, 0, 0],
              [0, 0, 1, 1]])

# Create and train the Hebbian network
hebbian_network = HebbianNetwork()
hebbian_network.fit(X)

# Test with a noisy pattern
test_pattern = np.array([1, 0, 0, 0])  # Noisy version of the first pattern
predicted_pattern = hebbian_network.predict(test_pattern)

print("Predicted Pattern:", predicted_pattern)
# Out:
# Predicted Pattern: [0.1 0.1 0.  0. ]

# %% [markdown]
# 10. write a program to implement feed forward neural network and feed backward neural network.

# %%
import numpy as np

class NeuralNetwork:
    def __init__(self, input_size, hidden_size, output_size):
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size

        # Initialize weights and biases
        self.weights_input_hidden = np.random.randn(self.input_size, self.hidden_size)
        self.bias_hidden = np.zeros((1, self.hidden_size))
        self.weights_hidden_output = np.random.randn(self.hidden_size, self.output_size)
        self.bias_output = np.zeros((1, self.output_size))

    def sigmoid(self, x):
        return 1 / (1 + np.exp(-x))

    def sigmoid_derivative(self, x):
        return x * (1 - x)

    def forward(self, X):
        # Forward propagation
        self.hidden_layer_input = np.dot(X, self.weights_input_hidden) + self.bias_hidden
        self.hidden_layer_output = self.sigmoid(self.hidden_layer_input)
        self.output_layer_input = np.dot(self.hidden_layer_output, self.weights_hidden_output) + self.bias_output
        self.output = self.sigmoid(self.output_layer_input)
        return self.output

    def backward(self, X, y, learning_rate):
        # Backpropagation
        output_error = y - self.output
        output_delta = output_error * self.sigmoid_derivative(self.output)

        hidden_error = output_delta.dot(self.weights_hidden_output.T)
        hidden_delta = hidden_error * self.sigmoid_derivative(self.hidden_layer_output)

        # Update weights and biases
        self.weights_hidden_output += self.hidden_layer_output.T.dot(output_delta) * learning_rate
        self.bias_output += np.sum(output_delta, axis=0, keepdims=True) * learning_rate
        self.weights_input_hidden += X.T.dot(hidden_delta) * learning_rate
        self.bias_hidden += np.sum(hidden_delta, axis=0, keepdims=True) * learning_rate

    def train(self, X, y, epochs, learning_rate):
        for epoch in range(epochs):
            self.forward(X)
            self.backward(X, y, learning_rate)

# Example usage
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([[0], [1], [1], [0]])  # XOR gate logic

nn = NeuralNetwork(input_size=2, hidden_size=2, output_size=1)
nn.train(X, y, epochs=10000, learning_rate=0.1)

print("Predictions:")
print(nn.forward(X))
# Out:
# Predictions:
# [[0.04601573]
#  [0.95261932]
#  [0.49693565]
#  [0.50354957]]

# %% [markdown]
# 11. Write a Program to demonstrate the usage of a CNN.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import datasets, layers, models

# Load and preprocess the MNIST dataset
(x_train, y_train), (x_test, y_test) = datasets.mnist.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
x_train = x_train.reshape((x_train.shape[0], 28, 28, 1))
x_test = x_test.reshape((x_test.shape[0], 28, 28, 1))
y_train = keras.utils.to_categorical(y_train, num_classes=10)
y_test = keras.utils.to_categorical(y_test, num_classes=10)

# Define the CNN model
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(10, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=5, batch_size=32)

# Evaluate the model
loss, accuracy = model.evaluate(x_test, y_test)
print('Test accuracy:', accuracy)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 58s 30ms/step - accuracy: 0.8919 - loss: 0.3527
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 55s 29ms/step - accuracy: 0.9828 - loss: 0.0562
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 82s 29ms/step - accuracy: 0.9872 - loss: 0.0394
# Epoch 4/5
# 1071/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 31ms/step - accuracy: 0.9912 - loss: 0.0284

# %% [markdown]
# 12. Write a Program to demonstrate the usage of a RNN.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence

# Set parameters
max_features = 10000  # Number of words to consider as features
maxlen = 500  # Cut texts after this number of words
batch_size = 32

# Load and preprocess the IMDB dataset
(input_train, y_train), (input_test, y_test) = imdb.load_data(num_words=max_features)
print(len(input_train), 'train sequences')
print(len(input_test), 'test sequences')

input_train = sequence.pad_sequences(input_train, maxlen=maxlen)
input_test = sequence.pad_sequences(input_test, maxlen=maxlen)
print('input_train shape:', input_train.shape)
print('input_test shape:', input_test.shape)

# Define the RNN model
model = keras.Sequential()
model.add(keras.layers.Embedding(max_features, 32))
model.add(keras.layers.SimpleRNN(32))
model.add(keras.layers.Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])

# Train the model
history = model.fit(input_train, y_train, epochs=10, batch_size=128, validation_split=0.2)

# Evaluate the model
loss, accuracy = model.evaluate(input_test, y_test)
print('Test accuracy:', accuracy)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# 25000 train sequences
# 25000 test sequences
# input_train shape: (25000, 500)
# input_test shape: (25000, 500)
# Epoch 1/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 25s 146ms/step - acc: 0.5358 - loss: 0.6880 - val_acc: 0.7676 - val_loss: 0.5393
# Epoch 2/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 24s 154ms/step - acc: 0.7768 - loss: 0.4949 - val_acc: 0.8294 - val_loss: 0.4108
# Epoch 3/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 40s 145ms/step - acc: 0.8504 - loss: 0.3572 - val_acc: 0.8066 - val_loss: 0.4316
# Epoch 4/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 43s 156ms/step - acc: 0.8860 - loss: 0.2865 - val_acc: 0.8508 - val_loss: 0.3750
# Epoch 5/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 40s 152ms/step - acc: 0.9218 - loss: 0.2037 - val_acc: 0.7832 - val_loss: 0.4872
# Epoch 6/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 41s 154ms/step - acc: 0.9503 - loss: 0.1415 - val_acc: 0.8104 - val_loss: 0.4602
# Epoch 7/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 24s 155ms/step - acc: 0.9682 - loss: 0.0949 - val_acc: 0.8084 - val_loss: 0.5408
# Epoch 8/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 41s 153ms/step - acc: 0.9804 - loss: 0.0631 - val_acc: 0.8148 - val_loss: 0.5772
# Epoch 9/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 41s 152ms/step - acc: 0.9886 - loss: 0.0411 - val_acc: 0.8282 - val_loss: 0.5758
# Epoch 10/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 41s 155ms/step - acc: 0.9951 - loss: 0.0216 - val_acc: 0.7882 - val_loss: 0.7216
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 18s 23ms/step - acc: 0.7938 - loss: 0.7125
# Test accuracy: 0.794920027256012
